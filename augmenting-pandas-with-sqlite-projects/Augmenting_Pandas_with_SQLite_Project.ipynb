# %% [markdown]
# # Project Notebook: Augmenting Pandas with SQLite

# %% [markdown]
# ## Question 1: Introduction

# %% [markdown]
# In this session, we explored a few different ways to work with larger datasets in pandas. In this guided project, we'll practice using some of the techniques we learned to analyze startup investments from Crunchbase.com.
#
# Every year, thousands of startup companies raise financing from investors. Each time a startup raises money, we refer to the event as a fundraising round. Crunchbase is a website that crowdsources information on the fundraising rounds of many startups. The Crunchbase user community submits, edits, and maintains most of the information in Crunchbase.
#
# In return, Crunchbase makes the data available through a Web application and a fee-based API. Before Crunchbase switched to the paid API model, multiple groups crawled the site and released the data online. Because the information on the startups and their fundraising rounds is always changing, the data set we'll be using isn't completely up to date.
#
# Throughout this project, we'll practice working with different memory constraints. In this step, let's assume we only have 10 megabytes of available memory. While crunchbase-investments.csv (https://bit.ly/3BPcobU) consumes 10.3 megabytes of disk space, we know from earlier lessons that pandas often requires 4 to 6 times amount of space in memory as the file does on disk (especially when there's many string columns).
#
#
# **Tasks**
#
# * Because the data set contains over 50,000 rows, you'll need to read the data set into dataframes using 5,000 row chunks to ensure that each chunk consumes much less than 10 megabytes of memory.
# * Across all of the chunks, become familiar with:
# 1. Each column's missing value counts.
# 2. Each column's memory footprint.
# 3. The total memory footprint of all of the chunks combined.
# 4. Which column(s) we can drop because they aren't useful for analysis.

# %%
# Your code goes here
# Dataset URL = https://bit.ly/3BPcobU
#

import pandas as pd

df = pd.read_csv('https://bit.ly/3BPcobU', encoding = "ISO-8859-1", chunksize=5000)

# %%
# Check columns for missing values

df = pd.read_csv('https://bit.ly/3BPcobU', encoding = "ISO-8859-1", chunksize=5000)
for chunk in df:
  print(chunk.isnull().sum())
# Out:
# company_permalink            0
# company_name                 0
# company_category_code       52
# company_country_code         0
# company_state_code          53
# company_region               0
# company_city                64
# investor_permalink           0
# investor_name                0
# investor_category_code    2557
# investor_country_code      778
# investor_state_code       1371
# investor_region              0
# investor_city              900
# funding_round_type           0
# funded_at                    0
# funded_month                 0
# funded_quarter               0
# funded_year                  0
# raised_amount_usd          653
# dtype: int64
# company_permalink            0
# company_name                 0
# company_category_code       51
# company_country_code         0
# company_state_code          43
# company_region               0
# company_city                45
# investor_permalink           0
# investor_name                0
# investor_category_code    5000
# investor_country_code      261
# investor_state_code        714
# investor_region              0
# investor_city              313
# funding_round_type           0
# funded_at                    0
# funded_month                 0
# funded_quarter               0
# funded_year                  0
# raised_amount_usd          239
# dtype: int64
# company_permalink            0
# company_name                 0
# company_category_code       82
# company_country_code         0
# company_state_code          56
# company_region               0
# company_city                44
# investor_permalink           0
# investor_name                0
# investor_category_code    5000
# investor_country_code      271
# investor_state_code        808
# investor_region              0
# investor_city              314
# funding_round_type           0
# funded_at                    0
# funded_month                 0
# funded_quarter               0
# funded_year                  0
# raised_amount_usd          221
# dtype: int64
# company_permalink            0
# company_name                 0
# company_category_code       57
# company_country_code         0
# company_state_code          36
# company_region               0
# company_city                44
# investor_permalink           0
# investor_name                0
# investor_category_code    5000
# investor_country_code      239
# investor_state_code        714
# investor_region              0
# investor_city              274
# funding_round_type           0
# funded_at                    0
# funded_month                 0
# funded_quarter               0
# funded_year                  0
# raised_amount_usd          299
# dtype: int64
# company_permalink            0
# company_name                 0
# company_category_code       69
# company_country_code         0
# company_state_code          40
# company_region               0
# company_city                41
# investor_permalink           0
# investor_name                0
# investor_category_code    5000
# investor_country_code      352
# investor_state_code       1116
# investor_region              0
# investor_city              434
# funding_round_type           0
# funded_at                    0
# funded_month                 0
# funded_quarter               0
# funded_year                  0
# raised_amount_usd          243
# dtype: int64
# company_permalink            0
# company_name                 0
# company_category_code       61
# company_country_code         0
# company_state_code          39
# company_region               0
# company_city                33
# investor_permalink           0
# investor_name                0
# investor_category_code    5000
# investor_country_code      218
# investor_state_code        732
# investor_region              0
# investor_city              238
# funding_round_type           0
# funded_at                    0
# funded_month                 0
# funded_quarter               0
# funded_year                  0
# raised_amount_usd          206
# dtype: int64
# company_permalink            1
# company_name                 1
# company_category_code       88
# company_country_code         1
# company_state_code          35
# company_region               1
# company_city                42
# investor_permalink           2
# investor_name                2
# investor_category_code    5000
# investor_country_code      313
# investor_state_code        922
# investor_region              2
# investor_city              339
# funding_round_type           3
# funded_at                    3
# funded_month                 3
# funded_quarter               3
# funded_year                  3
# raised_amount_usd          287
# dtype: int64
# company_permalink            0
# company_name                 0
# company_category_code       83
# company_country_code         0
# company_state_code          65
# company_region               0
# company_city                55
# investor_permalink           0
# investor_name                0
# investor_category_code    5000
# investor_country_code      267
# investor_state_code        775
# investor_region              0
# investor_city              334
# funding_round_type           0
# funded_at                    0
# funded_month                 0
# funded_quarter               0
# funded_year                  0
# raised_amount_usd          368
# dtype: int64
# company_permalink            0
# company_name                 0
# company_category_code       75
# company_country_code         0
# company_state_code          50
# company_region               0
# company_city                50
# investor_permalink           0
# investor_name                0
# investor_category_code    5000
# investor_country_code     1432
# investor_state_code       1787
# investor_region              0
# investor_city             1464
# funding_round_type           0
# funded_at                    0
# funded_month                 0
# funded_quarter               0
# funded_year                  0
# raised_amount_usd          324
# dtype: int64
# company_permalink            0
# company_name                 0
# company_category_code       15
# company_country_code         0
# company_state_code          46
# company_region               0
# company_city                70
# investor_permalink           0
# investor_name                0
# investor_category_code    5000
# investor_country_code     5000
# investor_state_code       5000
# investor_region              0
# investor_city             5000
# funding_round_type           0
# funded_at                    0
# funded_month                 0
# funded_quarter               0
# funded_year                  0
# raised_amount_usd          469
# dtype: int64
# company_permalink            0
# company_name                 0
# company_category_code       10
# company_country_code         0
# company_state_code          29
# company_region               0
# company_city                45
# investor_permalink           0
# investor_name                0
# investor_category_code    2870
# investor_country_code     2870
# investor_state_code       2870
# investor_region              0
# investor_city             2870
# funding_round_type           0
# funded_at                    0
# funded_month                 0
# funded_quarter               0
# funded_year                  0
# raised_amount_usd          290
# dtype: int64

# %%
# Check each columns memory footprint

chunk_iter = pd.read_csv('https://bit.ly/3BPcobU', encoding = "ISO-8859-1", chunksize=5000)
for chunk in chunk_iter:
  for col in chunk:
    print(chunk.memory_usage(deep=True)/(1024*1024))
# Out:
# Index                     0.000122
# company_permalink         0.365729
# company_name              0.323832
# company_category_code     0.308253
# company_country_code      0.286102
# company_state_code        0.279969
# company_region            0.308153
# company_city              0.315244
# investor_permalink        0.406121
# investor_name             0.340663
# investor_category_code    0.228371
# investor_country_code     0.265327
# investor_state_code       0.246032
# investor_region           0.306885
# investor_city             0.286545
# funding_round_type        0.305766
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000122
# company_permalink         0.365729
# company_name              0.323832
# company_category_code     0.308253
# company_country_code      0.286102
# company_state_code        0.279969
# company_region            0.308153
# company_city              0.315244
# investor_permalink        0.406121
# investor_name             0.340663
# investor_category_code    0.228371
# investor_country_code     0.265327
# investor_state_code       0.246032
# investor_region           0.306885
# investor_city             0.286545
# funding_round_type        0.305766
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000122
# company_permalink         0.365729
# company_name              0.323832
# company_category_code     0.308253
# company_country_code      0.286102
# company_state_code        0.279969
# company_region            0.308153
# company_city              0.315244
# investor_permalink        0.406121
# investor_name             0.340663
# investor_category_code    0.228371
# investor_country_code     0.265327
# investor_state_code       0.246032
# investor_region           0.306885
# investor_city             0.286545
# funding_round_type        0.305766
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000122
# company_permalink         0.365729
# company_name              0.323832
# company_category_code     0.308253
# company_country_code      0.286102
# company_state_code        0.279969
# company_region            0.308153
# company_city              0.315244
# investor_permalink        0.406121
# investor_name             0.340663
# investor_category_code    0.228371
# investor_country_code     0.265327
# investor_state_code       0.246032
# investor_region           0.306885
# investor_city             0.286545
# funding_round_type        0.305766
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000122
# company_permalink         0.365729
# company_name              0.323832
# company_category_code     0.308253
# company_country_code      0.286102
# company_state_code        0.279969
# company_region            0.308153
# company_city              0.315244
# investor_permalink        0.406121
# investor_name             0.340663
# investor_category_code    0.228371
# investor_country_code     0.265327
# investor_state_code       0.246032
# investor_region           0.306885
# investor_city             0.286545
# funding_round_type        0.305766
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000122
# company_permalink         0.365729
# company_name              0.323832
# company_category_code     0.308253
# company_country_code      0.286102
# company_state_code        0.279969
# company_region            0.308153
# company_city              0.315244
# investor_permalink        0.406121
# investor_name             0.340663
# investor_category_code    0.228371
# investor_country_code     0.265327
# investor_state_code       0.246032
# investor_region           0.306885
# investor_city             0.286545
# funding_round_type        0.305766
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000122
# company_permalink         0.365729
# company_name              0.323832
# company_category_code     0.308253
# company_country_code      0.286102
# company_state_code        0.279969
# company_region            0.308153
# company_city              0.315244
# investor_permalink        0.406121
# investor_name             0.340663
# investor_category_code    0.228371
# investor_country_code     0.265327
# investor_state_code       0.246032
# investor_region           0.306885
# investor_city             0.286545
# funding_round_type        0.305766
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000122
# company_permalink         0.365729
# company_name              0.323832
# company_category_code     0.308253
# company_country_code      0.286102
# company_state_code        0.279969
# company_region            0.308153
# company_city              0.315244
# investor_permalink        0.406121
# investor_name             0.340663
# investor_category_code    0.228371
# investor_country_code     0.265327
# investor_state_code       0.246032
# investor_region           0.306885
# investor_city             0.286545
# funding_round_type        0.305766
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000122
# company_permalink         0.365729
# company_name              0.323832
# company_category_code     0.308253
# company_country_code      0.286102
# company_state_code        0.279969
# company_region            0.308153
# company_city              0.315244
# investor_permalink        0.406121
# investor_name             0.340663
# investor_category_code    0.228371
# investor_country_code     0.265327
# investor_state_code       0.246032
# investor_region           0.306885
# investor_city             0.286545
# funding_round_type        0.305766
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000122
# company_permalink         0.365729
# company_name              0.323832
# company_category_code     0.308253
# company_country_code      0.286102
# company_state_code        0.279969
# company_region            0.308153
# company_city              0.315244
# investor_permalink        0.406121
# investor_name             0.340663
# investor_category_code    0.228371
# investor_country_code     0.265327
# investor_state_code       0.246032
# investor_region           0.306885
# investor_city             0.286545
# funding_round_type        0.305766
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000122
# company_permalink         0.365729
# company_name              0.323832
# company_category_code     0.308253
# company_country_code      0.286102
# company_state_code        0.279969
# company_region            0.308153
# company_city              0.315244
# investor_permalink        0.406121
# investor_name             0.340663
# investor_category_code    0.228371
# investor_country_code     0.265327
# investor_state_code       0.246032
# investor_region           0.306885
# investor_city             0.286545
# funding_round_type        0.305766
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000122
# company_permalink         0.365729
# company_name              0.323832
# company_category_code     0.308253
# company_country_code      0.286102
# company_state_code        0.279969
# company_region            0.308153
# company_city              0.315244
# investor_permalink        0.406121
# investor_name             0.340663
# investor_category_code    0.228371
# investor_country_code     0.265327
# investor_state_code       0.246032
# investor_region           0.306885
# investor_city             0.286545
# funding_round_type        0.305766
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000122
# company_permalink         0.365729
# company_name              0.323832
# company_category_code     0.308253
# company_country_code      0.286102
# company_state_code        0.279969
# company_region            0.308153
# company_city              0.315244
# investor_permalink        0.406121
# investor_name             0.340663
# investor_category_code    0.228371
# investor_country_code     0.265327
# investor_state_code       0.246032
# investor_region           0.306885
# investor_city             0.286545
# funding_round_type        0.305766
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000122
# company_permalink         0.365729
# company_name              0.323832
# company_category_code     0.308253
# company_country_code      0.286102
# company_state_code        0.279969
# company_region            0.308153
# company_city              0.315244
# investor_permalink        0.406121
# investor_name             0.340663
# investor_category_code    0.228371
# investor_country_code     0.265327
# investor_state_code       0.246032
# investor_region           0.306885
# investor_city             0.286545
# funding_round_type        0.305766
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000122
# company_permalink         0.365729
# company_name              0.323832
# company_category_code     0.308253
# company_country_code      0.286102
# company_state_code        0.279969
# company_region            0.308153
# company_city              0.315244
# investor_permalink        0.406121
# investor_name             0.340663
# investor_category_code    0.228371
# investor_country_code     0.265327
# investor_state_code       0.246032
# investor_region           0.306885
# investor_city             0.286545
# funding_round_type        0.305766
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000122
# company_permalink         0.365729
# company_name              0.323832
# company_category_code     0.308253
# company_country_code      0.286102
# company_state_code        0.279969
# company_region            0.308153
# company_city              0.315244
# investor_permalink        0.406121
# investor_name             0.340663
# investor_category_code    0.228371
# investor_country_code     0.265327
# investor_state_code       0.246032
# investor_region           0.306885
# investor_city             0.286545
# funding_round_type        0.305766
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000122
# company_permalink         0.365729
# company_name              0.323832
# company_category_code     0.308253
# company_country_code      0.286102
# company_state_code        0.279969
# company_region            0.308153
# company_city              0.315244
# investor_permalink        0.406121
# investor_name             0.340663
# investor_category_code    0.228371
# investor_country_code     0.265327
# investor_state_code       0.246032
# investor_region           0.306885
# investor_city             0.286545
# funding_round_type        0.305766
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000122
# company_permalink         0.365729
# company_name              0.323832
# company_category_code     0.308253
# company_country_code      0.286102
# company_state_code        0.279969
# company_region            0.308153
# company_city              0.315244
# investor_permalink        0.406121
# investor_name             0.340663
# investor_category_code    0.228371
# investor_country_code     0.265327
# investor_state_code       0.246032
# investor_region           0.306885
# investor_city             0.286545
# funding_round_type        0.305766
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000122
# company_permalink         0.365729
# company_name              0.323832
# company_category_code     0.308253
# company_country_code      0.286102
# company_state_code        0.279969
# company_region            0.308153
# company_city              0.315244
# investor_permalink        0.406121
# investor_name             0.340663
# investor_category_code    0.228371
# investor_country_code     0.265327
# investor_state_code       0.246032
# investor_region           0.306885
# investor_city             0.286545
# funding_round_type        0.305766
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000122
# company_permalink         0.365729
# company_name              0.323832
# company_category_code     0.308253
# company_country_code      0.286102
# company_state_code        0.279969
# company_region            0.308153
# company_city              0.315244
# investor_permalink        0.406121
# investor_name             0.340663
# investor_category_code    0.228371
# investor_country_code     0.265327
# investor_state_code       0.246032
# investor_region           0.306885
# investor_city             0.286545
# funding_round_type        0.305766
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.367855
# company_name              0.326042
# company_category_code     0.309870
# company_country_code      0.286102
# company_state_code        0.280227
# company_region            0.307571
# company_city              0.316006
# investor_permalink        0.470901
# investor_name             0.356913
# investor_category_code    0.038147
# investor_country_code     0.279133
# investor_state_code       0.262949
# investor_region           0.304610
# investor_city             0.306560
# funding_round_type        0.309094
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.367855
# company_name              0.326042
# company_category_code     0.309870
# company_country_code      0.286102
# company_state_code        0.280227
# company_region            0.307571
# company_city              0.316006
# investor_permalink        0.470901
# investor_name             0.356913
# investor_category_code    0.038147
# investor_country_code     0.279133
# investor_state_code       0.262949
# investor_region           0.304610
# investor_city             0.306560
# funding_round_type        0.309094
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.367855
# company_name              0.326042
# company_category_code     0.309870
# company_country_code      0.286102
# company_state_code        0.280227
# company_region            0.307571
# company_city              0.316006
# investor_permalink        0.470901
# investor_name             0.356913
# investor_category_code    0.038147
# investor_country_code     0.279133
# investor_state_code       0.262949
# investor_region           0.304610
# investor_city             0.306560
# funding_round_type        0.309094
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.367855
# company_name              0.326042
# company_category_code     0.309870
# company_country_code      0.286102
# company_state_code        0.280227
# company_region            0.307571
# company_city              0.316006
# investor_permalink        0.470901
# investor_name             0.356913
# investor_category_code    0.038147
# investor_country_code     0.279133
# investor_state_code       0.262949
# investor_region           0.304610
# investor_city             0.306560
# funding_round_type        0.309094
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.367855
# company_name              0.326042
# company_category_code     0.309870
# company_country_code      0.286102
# company_state_code        0.280227
# company_region            0.307571
# company_city              0.316006
# investor_permalink        0.470901
# investor_name             0.356913
# investor_category_code    0.038147
# investor_country_code     0.279133
# investor_state_code       0.262949
# investor_region           0.304610
# investor_city             0.306560
# funding_round_type        0.309094
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.367855
# company_name              0.326042
# company_category_code     0.309870
# company_country_code      0.286102
# company_state_code        0.280227
# company_region            0.307571
# company_city              0.316006
# investor_permalink        0.470901
# investor_name             0.356913
# investor_category_code    0.038147
# investor_country_code     0.279133
# investor_state_code       0.262949
# investor_region           0.304610
# investor_city             0.306560
# funding_round_type        0.309094
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.367855
# company_name              0.326042
# company_category_code     0.309870
# company_country_code      0.286102
# company_state_code        0.280227
# company_region            0.307571
# company_city              0.316006
# investor_permalink        0.470901
# investor_name             0.356913
# investor_category_code    0.038147
# investor_country_code     0.279133
# investor_state_code       0.262949
# investor_region           0.304610
# investor_city             0.306560
# funding_round_type        0.309094
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.367855
# company_name              0.326042
# company_category_code     0.309870
# company_country_code      0.286102
# company_state_code        0.280227
# company_region            0.307571
# company_city              0.316006
# investor_permalink        0.470901
# investor_name             0.356913
# investor_category_code    0.038147
# investor_country_code     0.279133
# investor_state_code       0.262949
# investor_region           0.304610
# investor_city             0.306560
# funding_round_type        0.309094
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.367855
# company_name              0.326042
# company_category_code     0.309870
# company_country_code      0.286102
# company_state_code        0.280227
# company_region            0.307571
# company_city              0.316006
# investor_permalink        0.470901
# investor_name             0.356913
# investor_category_code    0.038147
# investor_country_code     0.279133
# investor_state_code       0.262949
# investor_region           0.304610
# investor_city             0.306560
# funding_round_type        0.309094
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.367855
# company_name              0.326042
# company_category_code     0.309870
# company_country_code      0.286102
# company_state_code        0.280227
# company_region            0.307571
# company_city              0.316006
# investor_permalink        0.470901
# investor_name             0.356913
# investor_category_code    0.038147
# investor_country_code     0.279133
# investor_state_code       0.262949
# investor_region           0.304610
# investor_city             0.306560
# funding_round_type        0.309094
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.367855
# company_name              0.326042
# company_category_code     0.309870
# company_country_code      0.286102
# company_state_code        0.280227
# company_region            0.307571
# company_city              0.316006
# investor_permalink        0.470901
# investor_name             0.356913
# investor_category_code    0.038147
# investor_country_code     0.279133
# investor_state_code       0.262949
# investor_region           0.304610
# investor_city             0.306560
# funding_round_type        0.309094
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.367855
# company_name              0.326042
# company_category_code     0.309870
# company_country_code      0.286102
# company_state_code        0.280227
# company_region            0.307571
# company_city              0.316006
# investor_permalink        0.470901
# investor_name             0.356913
# investor_category_code    0.038147
# investor_country_code     0.279133
# investor_state_code       0.262949
# investor_region           0.304610
# investor_city             0.306560
# funding_round_type        0.309094
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.367855
# company_name              0.326042
# company_category_code     0.309870
# company_country_code      0.286102
# company_state_code        0.280227
# company_region            0.307571
# company_city              0.316006
# investor_permalink        0.470901
# investor_name             0.356913
# investor_category_code    0.038147
# investor_country_code     0.279133
# investor_state_code       0.262949
# investor_region           0.304610
# investor_city             0.306560
# funding_round_type        0.309094
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.367855
# company_name              0.326042
# company_category_code     0.309870
# company_country_code      0.286102
# company_state_code        0.280227
# company_region            0.307571
# company_city              0.316006
# investor_permalink        0.470901
# investor_name             0.356913
# investor_category_code    0.038147
# investor_country_code     0.279133
# investor_state_code       0.262949
# investor_region           0.304610
# investor_city             0.306560
# funding_round_type        0.309094
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.367855
# company_name              0.326042
# company_category_code     0.309870
# company_country_code      0.286102
# company_state_code        0.280227
# company_region            0.307571
# company_city              0.316006
# investor_permalink        0.470901
# investor_name             0.356913
# investor_category_code    0.038147
# investor_country_code     0.279133
# investor_state_code       0.262949
# investor_region           0.304610
# investor_city             0.306560
# funding_round_type        0.309094
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.367855
# company_name              0.326042
# company_category_code     0.309870
# company_country_code      0.286102
# company_state_code        0.280227
# company_region            0.307571
# company_city              0.316006
# investor_permalink        0.470901
# investor_name             0.356913
# investor_category_code    0.038147
# investor_country_code     0.279133
# investor_state_code       0.262949
# investor_region           0.304610
# investor_city             0.306560
# funding_round_type        0.309094
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.367855
# company_name              0.326042
# company_category_code     0.309870
# company_country_code      0.286102
# company_state_code        0.280227
# company_region            0.307571
# company_city              0.316006
# investor_permalink        0.470901
# investor_name             0.356913
# investor_category_code    0.038147
# investor_country_code     0.279133
# investor_state_code       0.262949
# investor_region           0.304610
# investor_city             0.306560
# funding_round_type        0.309094
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.367855
# company_name              0.326042
# company_category_code     0.309870
# company_country_code      0.286102
# company_state_code        0.280227
# company_region            0.307571
# company_city              0.316006
# investor_permalink        0.470901
# investor_name             0.356913
# investor_category_code    0.038147
# investor_country_code     0.279133
# investor_state_code       0.262949
# investor_region           0.304610
# investor_city             0.306560
# funding_round_type        0.309094
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.367855
# company_name              0.326042
# company_category_code     0.309870
# company_country_code      0.286102
# company_state_code        0.280227
# company_region            0.307571
# company_city              0.316006
# investor_permalink        0.470901
# investor_name             0.356913
# investor_category_code    0.038147
# investor_country_code     0.279133
# investor_state_code       0.262949
# investor_region           0.304610
# investor_city             0.306560
# funding_round_type        0.309094
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.367855
# company_name              0.326042
# company_category_code     0.309870
# company_country_code      0.286102
# company_state_code        0.280227
# company_region            0.307571
# company_city              0.316006
# investor_permalink        0.470901
# investor_name             0.356913
# investor_category_code    0.038147
# investor_country_code     0.279133
# investor_state_code       0.262949
# investor_region           0.304610
# investor_city             0.306560
# funding_round_type        0.309094
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.368694
# company_name              0.326862
# company_category_code     0.309110
# company_country_code      0.286102
# company_state_code        0.279892
# company_region            0.308001
# company_city              0.315769
# investor_permalink        0.472581
# investor_name             0.360038
# investor_category_code    0.038147
# investor_country_code     0.278866
# investor_state_code       0.260529
# investor_region           0.308448
# investor_city             0.306814
# funding_round_type        0.308946
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.368694
# company_name              0.326862
# company_category_code     0.309110
# company_country_code      0.286102
# company_state_code        0.279892
# company_region            0.308001
# company_city              0.315769
# investor_permalink        0.472581
# investor_name             0.360038
# investor_category_code    0.038147
# investor_country_code     0.278866
# investor_state_code       0.260529
# investor_region           0.308448
# investor_city             0.306814
# funding_round_type        0.308946
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.368694
# company_name              0.326862
# company_category_code     0.309110
# company_country_code      0.286102
# company_state_code        0.279892
# company_region            0.308001
# company_city              0.315769
# investor_permalink        0.472581
# investor_name             0.360038
# investor_category_code    0.038147
# investor_country_code     0.278866
# investor_state_code       0.260529
# investor_region           0.308448
# investor_city             0.306814
# funding_round_type        0.308946
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.368694
# company_name              0.326862
# company_category_code     0.309110
# company_country_code      0.286102
# company_state_code        0.279892
# company_region            0.308001
# company_city              0.315769
# investor_permalink        0.472581
# investor_name             0.360038
# investor_category_code    0.038147
# investor_country_code     0.278866
# investor_state_code       0.260529
# investor_region           0.308448
# investor_city             0.306814
# funding_round_type        0.308946
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.368694
# company_name              0.326862
# company_category_code     0.309110
# company_country_code      0.286102
# company_state_code        0.279892
# company_region            0.308001
# company_city              0.315769
# investor_permalink        0.472581
# investor_name             0.360038
# investor_category_code    0.038147
# investor_country_code     0.278866
# investor_state_code       0.260529
# investor_region           0.308448
# investor_city             0.306814
# funding_round_type        0.308946
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.368694
# company_name              0.326862
# company_category_code     0.309110
# company_country_code      0.286102
# company_state_code        0.279892
# company_region            0.308001
# company_city              0.315769
# investor_permalink        0.472581
# investor_name             0.360038
# investor_category_code    0.038147
# investor_country_code     0.278866
# investor_state_code       0.260529
# investor_region           0.308448
# investor_city             0.306814
# funding_round_type        0.308946
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.368694
# company_name              0.326862
# company_category_code     0.309110
# company_country_code      0.286102
# company_state_code        0.279892
# company_region            0.308001
# company_city              0.315769
# investor_permalink        0.472581
# investor_name             0.360038
# investor_category_code    0.038147
# investor_country_code     0.278866
# investor_state_code       0.260529
# investor_region           0.308448
# investor_city             0.306814
# funding_round_type        0.308946
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.368694
# company_name              0.326862
# company_category_code     0.309110
# company_country_code      0.286102
# company_state_code        0.279892
# company_region            0.308001
# company_city              0.315769
# investor_permalink        0.472581
# investor_name             0.360038
# investor_category_code    0.038147
# investor_country_code     0.278866
# investor_state_code       0.260529
# investor_region           0.308448
# investor_city             0.306814
# funding_round_type        0.308946
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.368694
# company_name              0.326862
# company_category_code     0.309110
# company_country_code      0.286102
# company_state_code        0.279892
# company_region            0.308001
# company_city              0.315769
# investor_permalink        0.472581
# investor_name             0.360038
# investor_category_code    0.038147
# investor_country_code     0.278866
# investor_state_code       0.260529
# investor_region           0.308448
# investor_city             0.306814
# funding_round_type        0.308946
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.368694
# company_name              0.326862
# company_category_code     0.309110
# company_country_code      0.286102
# company_state_code        0.279892
# company_region            0.308001
# company_city              0.315769
# investor_permalink        0.472581
# investor_name             0.360038
# investor_category_code    0.038147
# investor_country_code     0.278866
# investor_state_code       0.260529
# investor_region           0.308448
# investor_city             0.306814
# funding_round_type        0.308946
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.368694
# company_name              0.326862
# company_category_code     0.309110
# company_country_code      0.286102
# company_state_code        0.279892
# company_region            0.308001
# company_city              0.315769
# investor_permalink        0.472581
# investor_name             0.360038
# investor_category_code    0.038147
# investor_country_code     0.278866
# investor_state_code       0.260529
# investor_region           0.308448
# investor_city             0.306814
# funding_round_type        0.308946
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.368694
# company_name              0.326862
# company_category_code     0.309110
# company_country_code      0.286102
# company_state_code        0.279892
# company_region            0.308001
# company_city              0.315769
# investor_permalink        0.472581
# investor_name             0.360038
# investor_category_code    0.038147
# investor_country_code     0.278866
# investor_state_code       0.260529
# investor_region           0.308448
# investor_city             0.306814
# funding_round_type        0.308946
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.368694
# company_name              0.326862
# company_category_code     0.309110
# company_country_code      0.286102
# company_state_code        0.279892
# company_region            0.308001
# company_city              0.315769
# investor_permalink        0.472581
# investor_name             0.360038
# investor_category_code    0.038147
# investor_country_code     0.278866
# investor_state_code       0.260529
# investor_region           0.308448
# investor_city             0.306814
# funding_round_type        0.308946
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.368694
# company_name              0.326862
# company_category_code     0.309110
# company_country_code      0.286102
# company_state_code        0.279892
# company_region            0.308001
# company_city              0.315769
# investor_permalink        0.472581
# investor_name             0.360038
# investor_category_code    0.038147
# investor_country_code     0.278866
# investor_state_code       0.260529
# investor_region           0.308448
# investor_city             0.306814
# funding_round_type        0.308946
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.368694
# company_name              0.326862
# company_category_code     0.309110
# company_country_code      0.286102
# company_state_code        0.279892
# company_region            0.308001
# company_city              0.315769
# investor_permalink        0.472581
# investor_name             0.360038
# investor_category_code    0.038147
# investor_country_code     0.278866
# investor_state_code       0.260529
# investor_region           0.308448
# investor_city             0.306814
# funding_round_type        0.308946
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.368694
# company_name              0.326862
# company_category_code     0.309110
# company_country_code      0.286102
# company_state_code        0.279892
# company_region            0.308001
# company_city              0.315769
# investor_permalink        0.472581
# investor_name             0.360038
# investor_category_code    0.038147
# investor_country_code     0.278866
# investor_state_code       0.260529
# investor_region           0.308448
# investor_city             0.306814
# funding_round_type        0.308946
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.368694
# company_name              0.326862
# company_category_code     0.309110
# company_country_code      0.286102
# company_state_code        0.279892
# company_region            0.308001
# company_city              0.315769
# investor_permalink        0.472581
# investor_name             0.360038
# investor_category_code    0.038147
# investor_country_code     0.278866
# investor_state_code       0.260529
# investor_region           0.308448
# investor_city             0.306814
# funding_round_type        0.308946
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.368694
# company_name              0.326862
# company_category_code     0.309110
# company_country_code      0.286102
# company_state_code        0.279892
# company_region            0.308001
# company_city              0.315769
# investor_permalink        0.472581
# investor_name             0.360038
# investor_category_code    0.038147
# investor_country_code     0.278866
# investor_state_code       0.260529
# investor_region           0.308448
# investor_city             0.306814
# funding_round_type        0.308946
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.368694
# company_name              0.326862
# company_category_code     0.309110
# company_country_code      0.286102
# company_state_code        0.279892
# company_region            0.308001
# company_city              0.315769
# investor_permalink        0.472581
# investor_name             0.360038
# investor_category_code    0.038147
# investor_country_code     0.278866
# investor_state_code       0.260529
# investor_region           0.308448
# investor_city             0.306814
# funding_round_type        0.308946
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.368694
# company_name              0.326862
# company_category_code     0.309110
# company_country_code      0.286102
# company_state_code        0.279892
# company_region            0.308001
# company_city              0.315769
# investor_permalink        0.472581
# investor_name             0.360038
# investor_category_code    0.038147
# investor_country_code     0.278866
# investor_state_code       0.260529
# investor_region           0.308448
# investor_city             0.306814
# funding_round_type        0.308946
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.366038
# company_name              0.323645
# company_category_code     0.309499
# company_country_code      0.286102
# company_state_code        0.280407
# company_region            0.306830
# company_city              0.316276
# investor_permalink        0.471095
# investor_name             0.360515
# investor_category_code    0.038147
# investor_country_code     0.279720
# investor_state_code       0.262949
# investor_region           0.305126
# investor_city             0.306919
# funding_round_type        0.308673
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.366038
# company_name              0.323645
# company_category_code     0.309499
# company_country_code      0.286102
# company_state_code        0.280407
# company_region            0.306830
# company_city              0.316276
# investor_permalink        0.471095
# investor_name             0.360515
# investor_category_code    0.038147
# investor_country_code     0.279720
# investor_state_code       0.262949
# investor_region           0.305126
# investor_city             0.306919
# funding_round_type        0.308673
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.366038
# company_name              0.323645
# company_category_code     0.309499
# company_country_code      0.286102
# company_state_code        0.280407
# company_region            0.306830
# company_city              0.316276
# investor_permalink        0.471095
# investor_name             0.360515
# investor_category_code    0.038147
# investor_country_code     0.279720
# investor_state_code       0.262949
# investor_region           0.305126
# investor_city             0.306919
# funding_round_type        0.308673
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.366038
# company_name              0.323645
# company_category_code     0.309499
# company_country_code      0.286102
# company_state_code        0.280407
# company_region            0.306830
# company_city              0.316276
# investor_permalink        0.471095
# investor_name             0.360515
# investor_category_code    0.038147
# investor_country_code     0.279720
# investor_state_code       0.262949
# investor_region           0.305126
# investor_city             0.306919
# funding_round_type        0.308673
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# ...
# funding_round_type        0.302800
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.357983
# company_name              0.315495
# company_category_code     0.306975
# company_country_code      0.286102
# company_state_code        0.280149
# company_region            0.307485
# company_city              0.317743
# investor_permalink        0.369493
# investor_name             0.331256
# investor_category_code    0.038147
# investor_country_code     0.038147
# investor_state_code       0.038147
# investor_region           0.305176
# investor_city             0.038147
# funding_round_type        0.302800
# funded_at                 0.319481
# funded_month              0.305176
# funded_quarter            0.305176
# funded_year               0.038147
# raised_amount_usd         0.038147
# dtype: float64
# Index                     0.000126
# company_permalink         0.205433
# company_name              0.180921
# company_category_code     0.176030
# company_country_code      0.164223
# company_state_code        0.160739
# company_region            0.176427
# company_city              0.182624
# investor_permalink        0.212440
# investor_name             0.190561
# investor_category_code    0.021896
# investor_country_code     0.021896
# investor_state_code       0.021896
# investor_region           0.175171
# investor_city             0.021896
# funding_round_type        0.173919
# funded_at                 0.183382
# funded_month              0.175171
# funded_quarter            0.175171
# funded_year               0.021896
# raised_amount_usd         0.021896
# dtype: float64
# Index                     0.000126
# company_permalink         0.205433
# company_name              0.180921
# company_category_code     0.176030
# company_country_code      0.164223
# company_state_code        0.160739
# company_region            0.176427
# company_city              0.182624
# investor_permalink        0.212440
# investor_name             0.190561
# investor_category_code    0.021896
# investor_country_code     0.021896
# investor_state_code       0.021896
# investor_region           0.175171
# investor_city             0.021896
# funding_round_type        0.173919
# funded_at                 0.183382
# funded_month              0.175171
# funded_quarter            0.175171
# funded_year               0.021896
# raised_amount_usd         0.021896
# dtype: float64
# Index                     0.000126
# company_permalink         0.205433
# company_name              0.180921
# company_category_code     0.176030
# company_country_code      0.164223
# company_state_code        0.160739
# company_region            0.176427
# company_city              0.182624
# investor_permalink        0.212440
# investor_name             0.190561
# investor_category_code    0.021896
# investor_country_code     0.021896
# investor_state_code       0.021896
# investor_region           0.175171
# investor_city             0.021896
# funding_round_type        0.173919
# funded_at                 0.183382
# funded_month              0.175171
# funded_quarter            0.175171
# funded_year               0.021896
# raised_amount_usd         0.021896
# dtype: float64
# Index                     0.000126
# company_permalink         0.205433
# company_name              0.180921
# company_category_code     0.176030
# company_country_code      0.164223
# company_state_code        0.160739
# company_region            0.176427
# company_city              0.182624
# investor_permalink        0.212440
# investor_name             0.190561
# investor_category_code    0.021896
# investor_country_code     0.021896
# investor_state_code       0.021896
# investor_region           0.175171
# investor_city             0.021896
# funding_round_type        0.173919
# funded_at                 0.183382
# funded_month              0.175171
# funded_quarter            0.175171
# funded_year               0.021896
# raised_amount_usd         0.021896
# dtype: float64
# Index                     0.000126
# company_permalink         0.205433
# company_name              0.180921
# company_category_code     0.176030
# company_country_code      0.164223
# company_state_code        0.160739
# company_region            0.176427
# company_city              0.182624
# investor_permalink        0.212440
# investor_name             0.190561
# investor_category_code    0.021896
# investor_country_code     0.021896
# investor_state_code       0.021896
# investor_region           0.175171
# investor_city             0.021896
# funding_round_type        0.173919
# funded_at                 0.183382
# funded_month              0.175171
# funded_quarter            0.175171
# funded_year               0.021896
# raised_amount_usd         0.021896
# dtype: float64
# Index                     0.000126
# company_permalink         0.205433
# company_name              0.180921
# company_category_code     0.176030
# company_country_code      0.164223
# company_state_code        0.160739
# company_region            0.176427
# company_city              0.182624
# investor_permalink        0.212440
# investor_name             0.190561
# investor_category_code    0.021896
# investor_country_code     0.021896
# investor_state_code       0.021896
# investor_region           0.175171
# investor_city             0.021896
# funding_round_type        0.173919
# funded_at                 0.183382
# funded_month              0.175171
# funded_quarter            0.175171
# funded_year               0.021896
# raised_amount_usd         0.021896
# dtype: float64
# Index                     0.000126
# company_permalink         0.205433
# company_name              0.180921
# company_category_code     0.176030
# company_country_code      0.164223
# company_state_code        0.160739
# company_region            0.176427
# company_city              0.182624
# investor_permalink        0.212440
# investor_name             0.190561
# investor_category_code    0.021896
# investor_country_code     0.021896
# investor_state_code       0.021896
# investor_region           0.175171
# investor_city             0.021896
# funding_round_type        0.173919
# funded_at                 0.183382
# funded_month              0.175171
# funded_quarter            0.175171
# funded_year               0.021896
# raised_amount_usd         0.021896
# dtype: float64
# Index                     0.000126
# company_permalink         0.205433
# company_name              0.180921
# company_category_code     0.176030
# company_country_code      0.164223
# company_state_code        0.160739
# company_region            0.176427
# company_city              0.182624
# investor_permalink        0.212440
# investor_name             0.190561
# investor_category_code    0.021896
# investor_country_code     0.021896
# investor_state_code       0.021896
# investor_region           0.175171
# investor_city             0.021896
# funding_round_type        0.173919
# funded_at                 0.183382
# funded_month              0.175171
# funded_quarter            0.175171
# funded_year               0.021896
# raised_amount_usd         0.021896
# dtype: float64
# Index                     0.000126
# company_permalink         0.205433
# company_name              0.180921
# company_category_code     0.176030
# company_country_code      0.164223
# company_state_code        0.160739
# company_region            0.176427
# company_city              0.182624
# investor_permalink        0.212440
# investor_name             0.190561
# investor_category_code    0.021896
# investor_country_code     0.021896
# investor_state_code       0.021896
# investor_region           0.175171
# investor_city             0.021896
# funding_round_type        0.173919
# funded_at                 0.183382
# funded_month              0.175171
# funded_quarter            0.175171
# funded_year               0.021896
# raised_amount_usd         0.021896
# dtype: float64
# Index                     0.000126
# company_permalink         0.205433
# company_name              0.180921
# company_category_code     0.176030
# company_country_code      0.164223
# company_state_code        0.160739
# company_region            0.176427
# company_city              0.182624
# investor_permalink        0.212440
# investor_name             0.190561
# investor_category_code    0.021896
# investor_country_code     0.021896
# investor_state_code       0.021896
# investor_region           0.175171
# investor_city             0.021896
# funding_round_type        0.173919
# funded_at                 0.183382
# funded_month              0.175171
# funded_quarter            0.175171
# funded_year               0.021896
# raised_amount_usd         0.021896
# dtype: float64
# Index                     0.000126
# company_permalink         0.205433
# company_name              0.180921
# company_category_code     0.176030
# company_country_code      0.164223
# company_state_code        0.160739
# company_region            0.176427
# company_city              0.182624
# investor_permalink        0.212440
# investor_name             0.190561
# investor_category_code    0.021896
# investor_country_code     0.021896
# investor_state_code       0.021896
# investor_region           0.175171
# investor_city             0.021896
# funding_round_type        0.173919
# funded_at                 0.183382
# funded_month              0.175171
# funded_quarter            0.175171
# funded_year               0.021896
# raised_amount_usd         0.021896
# dtype: float64
# Index                     0.000126
# company_permalink         0.205433
# company_name              0.180921
# company_category_code     0.176030
# company_country_code      0.164223
# company_state_code        0.160739
# company_region            0.176427
# company_city              0.182624
# investor_permalink        0.212440
# investor_name             0.190561
# investor_category_code    0.021896
# investor_country_code     0.021896
# investor_state_code       0.021896
# investor_region           0.175171
# investor_city             0.021896
# funding_round_type        0.173919
# funded_at                 0.183382
# funded_month              0.175171
# funded_quarter            0.175171
# funded_year               0.021896
# raised_amount_usd         0.021896
# dtype: float64
# Index                     0.000126
# company_permalink         0.205433
# company_name              0.180921
# company_category_code     0.176030
# company_country_code      0.164223
# company_state_code        0.160739
# company_region            0.176427
# company_city              0.182624
# investor_permalink        0.212440
# investor_name             0.190561
# investor_category_code    0.021896
# investor_country_code     0.021896
# investor_state_code       0.021896
# investor_region           0.175171
# investor_city             0.021896
# funding_round_type        0.173919
# funded_at                 0.183382
# funded_month              0.175171
# funded_quarter            0.175171
# funded_year               0.021896
# raised_amount_usd         0.021896
# dtype: float64
# Index                     0.000126
# company_permalink         0.205433
# company_name              0.180921
# company_category_code     0.176030
# company_country_code      0.164223
# company_state_code        0.160739
# company_region            0.176427
# company_city              0.182624
# investor_permalink        0.212440
# investor_name             0.190561
# investor_category_code    0.021896
# investor_country_code     0.021896
# investor_state_code       0.021896
# investor_region           0.175171
# investor_city             0.021896
# funding_round_type        0.173919
# funded_at                 0.183382
# funded_month              0.175171
# funded_quarter            0.175171
# funded_year               0.021896
# raised_amount_usd         0.021896
# dtype: float64
# Index                     0.000126
# company_permalink         0.205433
# company_name              0.180921
# company_category_code     0.176030
# company_country_code      0.164223
# company_state_code        0.160739
# company_region            0.176427
# company_city              0.182624
# investor_permalink        0.212440
# investor_name             0.190561
# investor_category_code    0.021896
# investor_country_code     0.021896
# investor_state_code       0.021896
# investor_region           0.175171
# investor_city             0.021896
# funding_round_type        0.173919
# funded_at                 0.183382
# funded_month              0.175171
# funded_quarter            0.175171
# funded_year               0.021896
# raised_amount_usd         0.021896
# dtype: float64
# Index                     0.000126
# company_permalink         0.205433
# company_name              0.180921
# company_category_code     0.176030
# company_country_code      0.164223
# company_state_code        0.160739
# company_region            0.176427
# company_city              0.182624
# investor_permalink        0.212440
# investor_name             0.190561
# investor_category_code    0.021896
# investor_country_code     0.021896
# investor_state_code       0.021896
# investor_region           0.175171
# investor_city             0.021896
# funding_round_type        0.173919
# funded_at                 0.183382
# funded_month              0.175171
# funded_quarter            0.175171
# funded_year               0.021896
# raised_amount_usd         0.021896
# dtype: float64
# Index                     0.000126
# company_permalink         0.205433
# company_name              0.180921
# company_category_code     0.176030
# company_country_code      0.164223
# company_state_code        0.160739
# company_region            0.176427
# company_city              0.182624
# investor_permalink        0.212440
# investor_name             0.190561
# investor_category_code    0.021896
# investor_country_code     0.021896
# investor_state_code       0.021896
# investor_region           0.175171
# investor_city             0.021896
# funding_round_type        0.173919
# funded_at                 0.183382
# funded_month              0.175171
# funded_quarter            0.175171
# funded_year               0.021896
# raised_amount_usd         0.021896
# dtype: float64
# Index                     0.000126
# company_permalink         0.205433
# company_name              0.180921
# company_category_code     0.176030
# company_country_code      0.164223
# company_state_code        0.160739
# company_region            0.176427
# company_city              0.182624
# investor_permalink        0.212440
# investor_name             0.190561
# investor_category_code    0.021896
# investor_country_code     0.021896
# investor_state_code       0.021896
# investor_region           0.175171
# investor_city             0.021896
# funding_round_type        0.173919
# funded_at                 0.183382
# funded_month              0.175171
# funded_quarter            0.175171
# funded_year               0.021896
# raised_amount_usd         0.021896
# dtype: float64
# Index                     0.000126
# company_permalink         0.205433
# company_name              0.180921
# company_category_code     0.176030
# company_country_code      0.164223
# company_state_code        0.160739
# company_region            0.176427
# company_city              0.182624
# investor_permalink        0.212440
# investor_name             0.190561
# investor_category_code    0.021896
# investor_country_code     0.021896
# investor_state_code       0.021896
# investor_region           0.175171
# investor_city             0.021896
# funding_round_type        0.173919
# funded_at                 0.183382
# funded_month              0.175171
# funded_quarter            0.175171
# funded_year               0.021896
# raised_amount_usd         0.021896
# dtype: float64
# Index                     0.000126
# company_permalink         0.205433
# company_name              0.180921
# company_category_code     0.176030
# company_country_code      0.164223
# company_state_code        0.160739
# company_region            0.176427
# company_city              0.182624
# investor_permalink        0.212440
# investor_name             0.190561
# investor_category_code    0.021896
# investor_country_code     0.021896
# investor_state_code       0.021896
# investor_region           0.175171
# investor_city             0.021896
# funding_round_type        0.173919
# funded_at                 0.183382
# funded_month              0.175171
# funded_quarter            0.175171
# funded_year               0.021896
# raised_amount_usd         0.021896
# dtype: float64

# %%
# Calculate the total memory usage across all of the chunks.

memory_footprints = 0 
chunk_iter = pd.read_csv('https://bit.ly/3BPcobU', encoding = "ISO-8859-1", chunksize=5000)
for chunk in chunk_iter:
  memory_footprints += (chunk.memory_usage(deep=True).sum()/(1024*1024))
print(f"{memory_footprints} MB")
# Out:
# 56.988911628723145 MB

# %% [markdown]
# We can drop 'investor_category_code' column as it is missing most values hence not useful for analysis.

# %% [markdown]
# ## Question 2: Selecting Data Types

# %% [markdown]
# Now that we have a good sense of the missing values, let's get familiar with the column types before adding the data into SQLite.
#
# **Tasks**
#
# * Identify the types for each column.
# * Identify the numeric columns we can represent using more space efficient types.
# For text columns:
# * Analyze the unique value counts across all of the chunks to see if we can convert them to a numeric type.
# * See if we clean clean any text columns and separate them into multiple numeric columns without adding any overhead when querying.
# * Make your changes to the code from the last step so that the overall memory the data consumes stays under 10 megabytes.

# %%
# Your code goes here

chunk_iter = pd.read_csv('https://bit.ly/3BPcobU', encoding = "ISO-8859-1", chunksize=5000)
for chunk in chunk_iter:
  chunk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       5000 non-null   object
#  1   company_name            5000 non-null   object
#  2   company_category_code   4948 non-null   object
#  3   company_country_code    5000 non-null   object
#  4   company_state_code      4947 non-null   object
#  5   company_region          5000 non-null   object
#  6   company_city            4936 non-null   object
#  7   investor_permalink      5000 non-null   object
#  8   investor_name           5000 non-null   object
#  9   investor_category_code  2443 non-null   object
#  10  investor_country_code   4222 non-null   object
#  11  investor_state_code     3629 non-null   object
#  12  investor_region         5000 non-null   object
#  13  investor_city           4100 non-null   object
#  14  funding_round_type      5000 non-null   object
#  15  funded_at               5000 non-null   object
#  16  funded_month            5000 non-null   object
#  17  funded_quarter          5000 non-null   object
#  18  funded_year             5000 non-null   int64
#  19  raised_amount_usd       4347 non-null   float64
# dtypes: float64(1), int64(1), object(18)
# memory usage: 781.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 5000 to 9999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       5000 non-null   object
#  1   company_name            5000 non-null   object
#  2   company_category_code   4949 non-null   object
#  3   company_country_code    5000 non-null   object
#  4   company_state_code      4957 non-null   object
#  5   company_region          5000 non-null   object
#  6   company_city            4955 non-null   object
#  7   investor_permalink      5000 non-null   object
#  8   investor_name           5000 non-null   object
#  9   investor_category_code  0 non-null      float64
#  10  investor_country_code   4739 non-null   object
#  11  investor_state_code     4286 non-null   object
#  12  investor_region         5000 non-null   object
#  13  investor_city           4687 non-null   object
#  14  funding_round_type      5000 non-null   object
#  15  funded_at               5000 non-null   object
#  16  funded_month            5000 non-null   object
#  17  funded_quarter          5000 non-null   object
#  18  funded_year             5000 non-null   int64
#  19  raised_amount_usd       4761 non-null   float64
# dtypes: float64(2), int64(1), object(17)
# memory usage: 781.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 10000 to 14999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       5000 non-null   object
#  1   company_name            5000 non-null   object
#  2   company_category_code   4918 non-null   object
#  3   company_country_code    5000 non-null   object
#  4   company_state_code      4944 non-null   object
#  5   company_region          5000 non-null   object
#  6   company_city            4956 non-null   object
#  7   investor_permalink      5000 non-null   object
#  8   investor_name           5000 non-null   object
#  9   investor_category_code  0 non-null      float64
#  10  investor_country_code   4729 non-null   object
#  11  investor_state_code     4192 non-null   object
#  12  investor_region         5000 non-null   object
#  13  investor_city           4686 non-null   object
#  14  funding_round_type      5000 non-null   object
#  15  funded_at               5000 non-null   object
#  16  funded_month            5000 non-null   object
#  17  funded_quarter          5000 non-null   object
#  18  funded_year             5000 non-null   int64
#  19  raised_amount_usd       4779 non-null   float64
# dtypes: float64(2), int64(1), object(17)
# memory usage: 781.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 15000 to 19999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       5000 non-null   object
#  1   company_name            5000 non-null   object
#  2   company_category_code   4943 non-null   object
#  3   company_country_code    5000 non-null   object
#  4   company_state_code      4964 non-null   object
#  5   company_region          5000 non-null   object
#  6   company_city            4956 non-null   object
#  7   investor_permalink      5000 non-null   object
#  8   investor_name           5000 non-null   object
#  9   investor_category_code  0 non-null      float64
#  10  investor_country_code   4761 non-null   object
#  11  investor_state_code     4286 non-null   object
#  12  investor_region         5000 non-null   object
#  13  investor_city           4726 non-null   object
#  14  funding_round_type      5000 non-null   object
#  15  funded_at               5000 non-null   object
#  16  funded_month            5000 non-null   object
#  17  funded_quarter          5000 non-null   object
#  18  funded_year             5000 non-null   int64
#  19  raised_amount_usd       4701 non-null   float64
# dtypes: float64(2), int64(1), object(17)
# memory usage: 781.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 20000 to 24999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       5000 non-null   object
#  1   company_name            5000 non-null   object
#  2   company_category_code   4931 non-null   object
#  3   company_country_code    5000 non-null   object
#  4   company_state_code      4960 non-null   object
#  5   company_region          5000 non-null   object
#  6   company_city            4959 non-null   object
#  7   investor_permalink      5000 non-null   object
#  8   investor_name           5000 non-null   object
#  9   investor_category_code  0 non-null      float64
#  10  investor_country_code   4648 non-null   object
#  11  investor_state_code     3884 non-null   object
#  12  investor_region         5000 non-null   object
#  13  investor_city           4566 non-null   object
#  14  funding_round_type      5000 non-null   object
#  15  funded_at               5000 non-null   object
#  16  funded_month            5000 non-null   object
#  17  funded_quarter          5000 non-null   object
#  18  funded_year             5000 non-null   int64
#  19  raised_amount_usd       4757 non-null   float64
# dtypes: float64(2), int64(1), object(17)
# memory usage: 781.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 25000 to 29999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       5000 non-null   object
#  1   company_name            5000 non-null   object
#  2   company_category_code   4939 non-null   object
#  3   company_country_code    5000 non-null   object
#  4   company_state_code      4961 non-null   object
#  5   company_region          5000 non-null   object
#  6   company_city            4967 non-null   object
#  7   investor_permalink      5000 non-null   object
#  8   investor_name           5000 non-null   object
#  9   investor_category_code  0 non-null      float64
#  10  investor_country_code   4782 non-null   object
#  11  investor_state_code     4268 non-null   object
#  12  investor_region         5000 non-null   object
#  13  investor_city           4762 non-null   object
#  14  funding_round_type      5000 non-null   object
#  15  funded_at               5000 non-null   object
#  16  funded_month            5000 non-null   object
#  17  funded_quarter          5000 non-null   object
#  18  funded_year             5000 non-null   int64
#  19  raised_amount_usd       4794 non-null   float64
# dtypes: float64(2), int64(1), object(17)
# memory usage: 781.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 30000 to 34999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       4999 non-null   object
#  1   company_name            4999 non-null   object
#  2   company_category_code   4912 non-null   object
#  3   company_country_code    4999 non-null   object
#  4   company_state_code      4965 non-null   object
#  5   company_region          4999 non-null   object
#  6   company_city            4958 non-null   object
#  7   investor_permalink      4998 non-null   object
#  8   investor_name           4998 non-null   object
#  9   investor_category_code  0 non-null      float64
#  10  investor_country_code   4687 non-null   object
#  11  investor_state_code     4078 non-null   object
#  12  investor_region         4998 non-null   object
#  13  investor_city           4661 non-null   object
#  14  funding_round_type      4997 non-null   object
#  15  funded_at               4997 non-null   object
#  16  funded_month            4997 non-null   object
#  17  funded_quarter          4997 non-null   object
#  18  funded_year             4997 non-null   float64
#  19  raised_amount_usd       4713 non-null   float64
# dtypes: float64(3), object(17)
# memory usage: 781.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 35000 to 39999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       5000 non-null   object
#  1   company_name            5000 non-null   object
#  2   company_category_code   4917 non-null   object
#  3   company_country_code    5000 non-null   object
#  4   company_state_code      4935 non-null   object
#  5   company_region          5000 non-null   object
#  6   company_city            4945 non-null   object
#  7   investor_permalink      5000 non-null   object
#  8   investor_name           5000 non-null   object
#  9   investor_category_code  0 non-null      float64
#  10  investor_country_code   4733 non-null   object
#  11  investor_state_code     4225 non-null   object
#  12  investor_region         5000 non-null   object
#  13  investor_city           4666 non-null   object
#  14  funding_round_type      5000 non-null   object
#  15  funded_at               5000 non-null   object
#  16  funded_month            5000 non-null   object
#  17  funded_quarter          5000 non-null   object
#  18  funded_year             5000 non-null   int64
#  19  raised_amount_usd       4632 non-null   float64
# dtypes: float64(2), int64(1), object(17)
# memory usage: 781.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 40000 to 44999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       5000 non-null   object
#  1   company_name            5000 non-null   object
#  2   company_category_code   4925 non-null   object
#  3   company_country_code    5000 non-null   object
#  4   company_state_code      4950 non-null   object
#  5   company_region          5000 non-null   object
#  6   company_city            4950 non-null   object
#  7   investor_permalink      5000 non-null   object
#  8   investor_name           5000 non-null   object
#  9   investor_category_code  0 non-null      float64
#  10  investor_country_code   3568 non-null   object
#  11  investor_state_code     3213 non-null   object
#  12  investor_region         5000 non-null   object
#  13  investor_city           3536 non-null   object
#  14  funding_round_type      5000 non-null   object
#  15  funded_at               5000 non-null   object
#  16  funded_month            5000 non-null   object
#  17  funded_quarter          5000 non-null   object
#  18  funded_year             5000 non-null   int64
#  19  raised_amount_usd       4676 non-null   float64
# dtypes: float64(2), int64(1), object(17)
# memory usage: 781.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 45000 to 49999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       5000 non-null   object
#  1   company_name            5000 non-null   object
#  2   company_category_code   4985 non-null   object
#  3   company_country_code    5000 non-null   object
#  4   company_state_code      4954 non-null   object
#  5   company_region          5000 non-null   object
#  6   company_city            4930 non-null   object
#  7   investor_permalink      5000 non-null   object
#  8   investor_name           5000 non-null   object
#  9   investor_category_code  0 non-null      float64
#  10  investor_country_code   0 non-null      float64
#  11  investor_state_code     0 non-null      float64
#  12  investor_region         5000 non-null   object
#  13  investor_city           0 non-null      float64
#  14  funding_round_type      5000 non-null   object
#  15  funded_at               5000 non-null   object
#  16  funded_month            5000 non-null   object
#  17  funded_quarter          5000 non-null   object
#  18  funded_year             5000 non-null   int64
#  19  raised_amount_usd       4531 non-null   float64
# dtypes: float64(5), int64(1), object(14)
# memory usage: 781.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2870 entries, 50000 to 52869
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       2870 non-null   object
#  1   company_name            2870 non-null   object
#  2   company_category_code   2860 non-null   object
#  3   company_country_code    2870 non-null   object
#  4   company_state_code      2841 non-null   object
#  5   company_region          2870 non-null   object
#  6   company_city            2825 non-null   object
#  7   investor_permalink      2870 non-null   object
#  8   investor_name           2870 non-null   object
#  9   investor_category_code  0 non-null      float64
#  10  investor_country_code   0 non-null      float64
#  11  investor_state_code     0 non-null      float64
#  12  investor_region         2870 non-null   object
#  13  investor_city           0 non-null      float64
#  14  funding_round_type      2870 non-null   object
#  15  funded_at               2870 non-null   object
#  16  funded_month            2870 non-null   object
#  17  funded_quarter          2870 non-null   object
#  18  funded_year             2870 non-null   int64
#  19  raised_amount_usd       2580 non-null   float64
# dtypes: float64(5), int64(1), object(14)
# memory usage: 448.6+ KB

# %% [markdown]
# ## Question 3: Loading Chunks Into SQLite

# %% [markdown]
# Now we're in good shape to start exploring and analyzing the data. The next step is to load each chunk into a table in a SQLite database so we can query the full data set.
#
# **Tasks**
#
# 1. Create and connect to a new SQLite database file.
# 2. Expand on the existing chunk processing code to export each chunk to a new table in the SQLite database.
# 3. Query the table and make sure the data types match up to what you had in mind for each column.

# %%
# Your code goes here

import sqlite3
import pandas as pd
conn = sqlite3.connect('crunchbase.db')
invest_iter = pd.read_csv('https://bit.ly/3BPcobU', encoding = "ISO-8859-1", chunksize=5000)
for chunk in invest_iter:
    chunk.to_sql("investments", conn, if_exists='append', index=False)

result = pd.read_sql('PRAGMA table_info(investments);', conn)
print(result)
# Out:
#     cid                    name     type  notnull dflt_value  pk
# 0     0       company_permalink     TEXT        0       None   0
# 1     1            company_name     TEXT        0       None   0
# 2     2   company_category_code     TEXT        0       None   0
# 3     3    company_country_code     TEXT        0       None   0
# 4     4      company_state_code     TEXT        0       None   0
# 5     5          company_region     TEXT        0       None   0
# 6     6            company_city     TEXT        0       None   0
# 7     7      investor_permalink     TEXT        0       None   0
# 8     8           investor_name     TEXT        0       None   0
# 9     9  investor_category_code     TEXT        0       None   0
# 10   10   investor_country_code     TEXT        0       None   0
# 11   11     investor_state_code     TEXT        0       None   0
# 12   12         investor_region     TEXT        0       None   0
# 13   13           investor_city     TEXT        0       None   0
# 14   14      funding_round_type     TEXT        0       None   0
# 15   15               funded_at     TEXT        0       None   0
# 16   16            funded_month     TEXT        0       None   0
# 17   17          funded_quarter     TEXT        0       None   0
# 18   18             funded_year  INTEGER        0       None   0
# 19   19       raised_amount_usd     REAL        0       None   0

# %% [markdown]
# ## Question 4: Next Steps

# %% [markdown]
# Now that the data is in SQLite, we can use the pandas SQLite workflow we learned in the last lesson to explore and analyze startup investments. Remember that each row isn't a unique company, but a unique investment from a single investor. This means that many startups will span multiple rows.
#
# Use the pandas SQLite workflow to answer the following questions:
#
# * What proportion of the total amount of funds did the top 10% raise? What about the top 1%? Compare these values to the proportions the bottom 10% and bottom 1% raised.
# * Which category of company attracted the most investments?
# * Which investor contributed the most money (across all startups)?
# * Which investors contributed the most money per startup?
# * Which funding round was the most popular? Which was the least popular?
#
# Here are some ideas for further exploration:
#
# * Repeat the tasks in this project using stricter memory constraints (under 1 megabyte).
# * Clean and analyze the other Crunchbase data sets from the same GitHub repo.
# * Understand which columns the data sets share, and how the data sets are linked.
# * Create a relational database design that links the data sets together and reduces the overall disk space the database file consumes.
#
# Use pandas to populate each table in the database, create the appropriate indexes, and so on.

# %%
# Your code goes here
q = 'select investor_name, sum(raised_amount_usd) as Raised_funds from investments group by investor_name order by sum(raised_amount_usd) desc;'
Raised = pd.read_sql(q, conn)
top_ten = len(Raised['investor_name'])/10
print(Raised[:20])
# Out:
#                        investor_name  Raised_funds
# 0   Kleiner Perkins Caufield & Byers  2.243565e+10
# 1          New Enterprise Associates  1.938508e+10
# 2                     Accel Partners  1.294425e+10
# 3                      Goldman Sachs  1.275092e+10
# 4                    Sequoia Capital  1.207880e+10
# 5                              Intel  1.193840e+10
# 6                             Google  1.161760e+10
# 7                        Time Warner  1.146000e+10
# 8                            Comcast  1.133800e+10
# 9                  Greylock Partners  9.921966e+09
# 10                       BrightHouse  9.400000e+09
# 11                     Intel Capital  9.391234e+09
# 12     Draper Fisher Jurvetson (DFJ)  9.002922e+09
# 13           Oak Investment Partners  8.700129e+09
# 14               Andreessen Horowitz  8.467348e+09
# 15       Lightspeed Venture Partners  8.281958e+09
# 16                         Benchmark  8.239898e+09
# 17                  Battery Ventures  8.109063e+09
# 18                 Redpoint Ventures  7.948755e+09
# 19         Bessemer Venture Partners  7.257410e+09

# %%
# Which category of company attracted the most investments?

q = 'select company_category_code, sum(raised_amount_usd) as Raised_funds from investments group by company_category_code order by sum(raised_amount_usd) desc;'
Raised = pd.read_sql(q, conn)
print(Raised[:10])
# Out:
#   company_category_code  Raised_funds
# 0               biotech  2.207928e+11
# 1              software  1.461690e+11
# 2                mobile  1.295548e+11
# 3             cleantech  1.054105e+11
# 4            enterprise  9.172185e+10
# 5                   web  8.028653e+10
# 6               medical  5.073421e+10
# 7           advertising  5.015332e+10
# 8             ecommerce  4.513444e+10
# 9       network_hosting  4.483937e+10

# %% [markdown]
# Biotech attracted the most investments

# %%
# Which investor contributed the most money (across all startups)?

q = 'select investor_name, sum(raised_amount_usd) as Raised_funds from investments group by investor_name order by sum(raised_amount_usd) desc;'
Raised = pd.read_sql(q, conn)
print(Raised[:5])
# Out:
#                       investor_name  Raised_funds
# 0  Kleiner Perkins Caufield & Byers  2.243565e+10
# 1         New Enterprise Associates  1.938508e+10
# 2                    Accel Partners  1.294425e+10
# 3                     Goldman Sachs  1.275092e+10
# 4                   Sequoia Capital  1.207880e+10

# %% [markdown]
# Kleiner Perkins Caufield & Byers contributed the most money across all startups.

# %%
# Which investors contributed the most money per startup?

q = 'select company_name, investor_name, sum(raised_amount_usd) as Raised_funds from investments group by investor_name, company_name order by sum(raised_amount_usd) desc;'
Raised = pd.read_sql(q, conn)
print(Raised[:20])
# Out:
#       company_name                     investor_name  Raised_funds
# 0        Clearwire                           Comcast  1.124000e+10
# 1        Clearwire                             Intel  1.124000e+10
# 2        Clearwire                       Time Warner  1.124000e+10
# 3        Clearwire                       BrightHouse  9.400000e+09
# 4        Clearwire                            Google  6.400000e+09
# 5        sigmacare            Marlin Equity Partners  5.200000e+09
# 6        Clearwire                     Sprint Nextel  5.000000e+09
# 7        Clearwire              Eagle River Holdings  4.840000e+09
# 8         Facebook          Digital Sky Technologies  3.400000e+09
# 9         Facebook                     Goldman Sachs  3.000000e+09
# 10         Groupon                  Battery Ventures  2.170000e+09
# 11         Groupon          Digital Sky Technologies  2.170000e+09
# 12  Wave Broadband                       GI Partners  2.100000e+09
# 13  Wave Broadband         Oak Hill Capital Partners  2.100000e+09
# 14             AOL                            Google  2.000000e+09
# 15         Groupon               Andreessen Horowitz  1.900000e+09
# 16         Groupon                 Fidelity Ventures  1.900000e+09
# 17         Groupon                 Greylock Partners  1.900000e+09
# 18         Groupon  Kleiner Perkins Caufield & Byers  1.900000e+09
# 19         Groupon                  Maverick Capital  1.900000e+09

# %% [markdown]
# Comcast, Intel, Time Warner, BrightHouse and Google contributed the most money per startup.

# %%
# Which funding round was the most popular? Which was the least popular?

q = 'select funding_round_type, sum(raised_amount_usd) as Raised_funds from investments group by funding_round_type order by sum(raised_amount_usd) desc;'
Raised = pd.read_sql(q, conn)
print(Raised[:10])
# Out:
#   funding_round_type  Raised_funds
# 0          series-c+  5.315069e+11
# 1            venture  2.611130e+11
# 2           series-b  2.566536e+11
# 3           series-a  1.730843e+11
# 4           post-ipo  6.183520e+10
# 5              other  3.701452e+10
# 6     private-equity  3.231975e+10
# 7              angel  9.924150e+09
# 8       crowdfunding  1.298300e+07
# 9               None           NaN

# %% [markdown]
# series-c+ was the most popular funding round. Crowdfunding was the least popular.
